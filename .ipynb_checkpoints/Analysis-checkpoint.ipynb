# %% [markdown]
# # The Math of Winning in Trading

# %% [markdown]
# The first thing that needs to be looked at is the mathematics of expectancy. This defines the interplay between the win ratio and the risk/reward ratio.
#
# The expectancy is defined as
#
# $$
# \text{Expectancy} = (\text{Win Rate} \cdot \text{Average Win}) - (\text{Loss Rate}\cdot\text{Average Loss}).
# $$
#
# As an example of how this works, assume a 50% win rate with a risk/reward profile of 1:2. This means that we gain \\$2 per trade that we win and lose \\$1 for every losing trade. With the 50% win rate, the expectancy of a trade is \\$0.50 of profit.
#
# It is important to note that this formula does not take slippage, commission drag or compounding into account. It also assumes a fixed risk/reward.

# %%
win_rate = 0.5
avg_win = 2
avg_loss = 1
expectancy = (win_rate * avg_win) - ((1 - win_rate) * avg_loss)
print(f"Expectancy is ${expectancy:.2f} per trade")
# Out:
# Expectancy is $0.50 per trade

# %% [markdown]
# ## Expectancy Curve
#
# The expectancy curve shows the inverse correlation of the risk/reward versus the win rate. Looking at the graph it can be seen that the more profit you shoot for, the more likely you'll lose.

# %%
# %pip install numpy matplotlib pandas
# Out:
# Requirement already satisfied: numpy in c:\users\darky\documents\repos\risktrader\venv\lib\site-packages (2.0.2)
# Requirement already satisfied: matplotlib in c:\users\darky\documents\repos\risktrader\venv\lib\site-packages (3.9.2)
# Requirement already satisfied: pandas in c:\users\darky\documents\repos\risktrader\venv\lib\site-packages (2.2.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\darky\documents\repos\risktrader\venv\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\darky\documents\repos\risktrader\venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\darky\documents\repos\risktrader\venv\lib\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\darky\documents\repos\risktrader\venv\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\darky\documents\repos\risktrader\venv\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\darky\documents\repos\risktrader\venv\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\darky\documents\repos\risktrader\venv\lib\site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\darky\documents\repos\risktrader\venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\darky\documents\repos\risktrader\venv\lib\site-packages (from matplotlib) (6.4.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\darky\documents\repos\risktrader\venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\darky\documents\repos\risktrader\venv\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\darky\documents\repos\risktrader\venv\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.20.1)
# Requirement already satisfied: six>=1.5 in c:\users\darky\documents\repos\risktrader\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
W = np.linspace(0.05, 0.95, 50)
y = 1 / W - 1 

plt.figure(figsize=(8, 8))
plt.plot(W, y, lw=3)
plt.grid(alpha=0.25,ls='--')
plt.xlabel('Win Rate')
plt.ylabel('Risk/Reward Ratio')
plt.title('Expectancy Curve')
plt.scatter(x=[0.5], y=[2], color='#0000ff')
plt.scatter(x=[0.6], y=[1.8], color='#4444ff')
plt.scatter(x=[0.65], y=[1.75], color='#8888ff')

# %% [markdown]
# ## Losing Streaks
#
# A losing streak is a number of trades that we lose in a row. From a probabilistic standpoint, at some point during trading you will encounter a losing trade. When this losing streak inevitably occurs, a large drawdown will happen to your portfolio. A simple estimation is calculated with
#
# $$
# \text{Estimated Losing Streak} = \ln \left( \text{Samples} \right) / \ln \left(1 - \text{Win Rate}\right).
# $$

# %%
import pandas as pd

# %%
X = np.linspace(0.01, 0.99, 101-2)
samples = 50000
Y = np.log(samples) / np.log(1.0 - X*100)
#df = pd.DataFrame([X, Y], columns=["Win Rate", "Estimated Losing Streak"])
# Out:
# C:\Users\Darky\AppData\Local\Temp\ipykernel_14968\2221628456.py:3: RuntimeWarning: divide by zero encountered in log
#   Y = np.log(samples) / np.log(1.0 - X*100)
# C:\Users\Darky\AppData\Local\Temp\ipykernel_14968\2221628456.py:3: RuntimeWarning: invalid value encountered in log
#   Y = np.log(samples) / np.log(1.0 - X*100)

# %%
np.log(samples) / np.log(1.0 - X)
# Out:
# array([-1076.55887745,  -535.56080947,  -355.22192394,  -265.04776191,
#         -210.93943007,  -174.86396265,  -149.09294457,  -129.76216725,
#         -114.72484712,  -102.69291315,   -92.84668289,   -84.63970055,
#          -77.69364976,   -71.7383038 ,   -66.57549565,   -62.05659931,
#          -58.06795888,   -54.52117462,   -51.34645658,   -48.48797207,
#          -45.90052255,   -43.54712666,   -41.39723394,   -39.42538494,
#          -37.61019306,   -35.93356122,   -34.38007269,   -32.93651243,
#          -31.59148741,   -30.33512297,   -29.15881782,   -28.05504508,
#          -27.01718944,   -26.03941308,   -25.11654451,   -24.24398604,
#          -23.41763616,   -22.63382421,   -21.8892551 ,   -21.18096231,
#          -20.50626775,   -19.86274739,   -19.24820164,   -18.66062979,
#          -18.09820782,   -17.55926918,   -17.04228787,   -16.54586383,
#          -16.06870989,   -15.60964047,   -15.16756148,   -14.74146143,
#          -14.3304035 ,   -13.93351854,   -13.54999875,   -13.17909207,
#          -12.82009714,   -12.47235874,   -12.13526369,   -11.80823718,
#          -11.49073933,   -11.1822622 ,   -10.88232692,   -10.59048116,
#          -10.30629669,   -10.02936725,    -9.75930643,    -9.49574578,
#           -9.23833291,    -8.9867298 ,    -8.74061106,    -8.49966224,
#           -8.2635782 ,    -8.03206142,    -7.80482024,    -7.58156701,
#           -7.36201619,    -7.14588211,    -6.93287662,    -6.72270623,
#           -6.51506893,    -6.30965022,    -6.1061184 ,    -5.90411859,
#           -5.70326514,    -5.50313185,    -5.30323881,    -5.10303465,
#           -4.90187163,    -4.69897   ,    -4.4933649 ,    -4.28382451,
#           -4.06871766,    -3.84578697,    -3.61173072,    -3.36135312,
#           -3.08558381,    -2.76577573,    -2.349485  ])

# %%
np.log(samples)
# Out:
# np.float64(10.819778284410283)

# %%
# %pip install scipy
# Out:
# Requirement already satisfied: scipy in c:\users\darky\documents\repos\risktrader\venv\lib\site-packages (1.13.1)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in c:\users\darky\documents\repos\risktrader\venv\lib\site-packages (from scipy) (2.0.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from scipy.stats import binom

n = 20
p = 0.75
r_values = list(range(n + 1))
mean, var = binom.stats(n, p)
dist = [binom.pmf(r, n, p) for r in r_values]

plt.figure(figsize=(10, 6))
plt.bar(r_values, dist)
plt.title(f'Probability of winning N trades (mean={mean:.2f})')
plt.xlabel('Number of winning trades')
plt.ylabel('Probability')
plt.gca().set_xlim([mean-3*var, mean+3*var])
# Out:
# (3.75, 26.25)

# %%
binom.interval(0.95, n, p)
# Out:
# (np.float64(11.0), np.float64(18.0))

# %% [markdown]
# ## Simulation

# %%
import random

# %%
balance = 1000
win_rate = 0.5
risk_reward = 2
risk = 0.01
n = 50

trades = []

for i in range(n):
    win = random.random() <= win_rate
    pre_balance = balance
    value_at_risk = balance * risk
    if win:
        balance += value_at_risk * risk_reward
    else:
        balance -= value_at_risk
        
    trades.append([win, pre_balance, balance])

df = pd.DataFrame(trades, columns=["Winning Trade", "Pre Balance", "Balance"])
df['Balance High Value'] = df['Balance'].cummax()
df['Drawdown'] = df['Balance'] / df['Balance High Value'] - 1.0

df
# Out:
#     Winning Trade  Pre Balance      Balance  Balance High Value  Drawdown
# 0           False  1000.000000   990.000000          990.000000  0.000000
# 1            True   990.000000  1009.800000         1009.800000  0.000000
# 2           False  1009.800000   999.702000         1009.800000 -0.010000
# 3           False   999.702000   989.704980         1009.800000 -0.019900
# 4            True   989.704980  1009.499080         1009.800000 -0.000298
# 5            True  1009.499080  1029.689061         1029.689061  0.000000
# 6           False  1029.689061  1019.392171         1029.689061 -0.010000
# 7           False  1019.392171  1009.198249         1029.689061 -0.019900
# 8           False  1009.198249   999.106266         1029.689061 -0.029701
# 9            True   999.106266  1019.088392         1029.689061 -0.010295
# 10           True  1019.088392  1039.470160         1039.470160  0.000000
# 11          False  1039.470160  1029.075458         1039.470160 -0.010000
# 12           True  1029.075458  1049.656967         1049.656967  0.000000
# 13           True  1049.656967  1070.650106         1070.650106  0.000000
# 14          False  1070.650106  1059.943605         1070.650106 -0.010000
# 15          False  1059.943605  1049.344169         1070.650106 -0.019900
# 16          False  1049.344169  1038.850728         1070.650106 -0.029701
# 17           True  1038.850728  1059.627742         1070.650106 -0.010295
# 18           True  1059.627742  1080.820297         1080.820297  0.000000
# 19          False  1080.820297  1070.012094         1080.820297 -0.010000
# 20          False  1070.012094  1059.311973         1080.820297 -0.019900
# 21           True  1059.311973  1080.498213         1080.820297 -0.000298
# 22           True  1080.498213  1102.108177         1102.108177  0.000000
# 23          False  1102.108177  1091.087095         1102.108177 -0.010000
# 24           True  1091.087095  1112.908837         1112.908837  0.000000
# 25          False  1112.908837  1101.779749         1112.908837 -0.010000
# 26          False  1101.779749  1090.761951         1112.908837 -0.019900
# 27          False  1090.761951  1079.854332         1112.908837 -0.029701
# 28           True  1079.854332  1101.451418         1112.908837 -0.010295
# 29           True  1101.451418  1123.480447         1123.480447  0.000000
# 30           True  1123.480447  1145.950056         1145.950056  0.000000
# 31           True  1145.950056  1168.869057         1168.869057  0.000000
# 32           True  1168.869057  1192.246438         1192.246438  0.000000
# 33          False  1192.246438  1180.323973         1192.246438 -0.010000
# 34           True  1180.323973  1203.930453         1203.930453  0.000000
# 35          False  1203.930453  1191.891148         1203.930453 -0.010000
# 36          False  1191.891148  1179.972237         1203.930453 -0.019900
# 37           True  1179.972237  1203.571682         1203.930453 -0.000298
# 38           True  1203.571682  1227.643115         1227.643115  0.000000
# 39           True  1227.643115  1252.195978         1252.195978  0.000000
# 40          False  1252.195978  1239.674018         1252.195978 -0.010000
# 41          False  1239.674018  1227.277278         1252.195978 -0.019900
# 42          False  1227.277278  1215.004505         1252.195978 -0.029701
# 43           True  1215.004505  1239.304595         1252.195978 -0.010295
# 44          False  1239.304595  1226.911549         1252.195978 -0.020192
# 45           True  1226.911549  1251.449780         1252.195978 -0.000596
# 46          False  1251.449780  1238.935282         1252.195978 -0.010590
# 47          False  1238.935282  1226.545929         1252.195978 -0.020484
# 48           True  1226.545929  1251.076848         1252.195978 -0.000894
# 49           True  1251.076848  1276.098385         1276.098385  0.000000

# %%
max_drawdown = df['Drawdown'].min()
end_balance = df.iloc[-1]['Balance']
profit = df.iloc[-1]['Balance'] / df.iloc[0]['Pre Balance'] - 1
end_balance, profit, max_drawdown
# Out:
# (np.float64(1276.0983848529454),
#  np.float64(0.27609838485294547),
#  np.float64(-0.0297010000000002))

# %%
def simulate(balance, win_rate, risk_reward, risk, n):   
    trades = []
    
    for i in range(n):
        win = random.random() <= win_rate
        pre_balance = balance
        value_at_risk = balance * risk
        if win:
            balance += value_at_risk * risk_reward
        else:
            balance -= value_at_risk
        profit = balance - pre_balance
        trades.append([win, pre_balance, profit, balance])
    
    df = pd.DataFrame(trades, columns=["Winning Trade", "Pre Balance", "Profit", "Balance"])
    df['Drawdown'] = df['Balance'] / df['Balance'].cummax() - 1.0

    max_drawdown = df['Drawdown'].min()
    end_balance = df.iloc[-1]['Balance']
    profit = df.iloc[-1]['Balance'] / df.iloc[0]['Pre Balance'] - 1
    
    return end_balance, profit, max_drawdown, df

# %%
b, pp, md, df = simulate(balance, win_rate, risk_reward, risk, n)
print(f"Balance = ${b:.2f}, Profit% = {pp*100:.2f}%, Max Drawdown = {abs(md*100):.2f}%")
df
# Out:
# Balance = $1402.63, Profit% = 9.92%, Max Drawdown = 5.85%
#     Winning Trade  Pre Balance     Profit      Balance  Drawdown
# 0           False  1276.098385 -12.760984  1263.337401  0.000000
# 1            True  1263.337401  25.266748  1288.604149  0.000000
# 2            True  1288.604149  25.772083  1314.376232  0.000000
# 3           False  1314.376232 -13.143762  1301.232470 -0.010000
# 4           False  1301.232470 -13.012325  1288.220145 -0.019900
# 5           False  1288.220145 -12.882201  1275.337944 -0.029701
# 6           False  1275.337944 -12.753379  1262.584564 -0.039404
# 7           False  1262.584564 -12.625846  1249.958718 -0.049010
# 8            True  1249.958718  24.999174  1274.957893 -0.029990
# 9           False  1274.957893 -12.749579  1262.208314 -0.039690
# 10          False  1262.208314 -12.622083  1249.586231 -0.049293
# 11           True  1249.586231  24.991725  1274.577955 -0.030279
# 12          False  1274.577955 -12.745780  1261.832176 -0.039976
# 13           True  1261.832176  25.236644  1287.068819 -0.020776
# 14           True  1287.068819  25.741376  1312.810196 -0.001191
# 15          False  1312.810196 -13.128102  1299.682094 -0.011180
# 16           True  1299.682094  25.993642  1325.675736  0.000000
# 17          False  1325.675736 -13.256757  1312.418978 -0.010000
# 18           True  1312.418978  26.248380  1338.667358  0.000000
# 19          False  1338.667358 -13.386674  1325.280684 -0.010000
# 20          False  1325.280684 -13.252807  1312.027877 -0.019900
# 21          False  1312.027877 -13.120279  1298.907599 -0.029701
# 22          False  1298.907599 -12.989076  1285.918523 -0.039404
# 23          False  1285.918523 -12.859185  1273.059337 -0.049010
# 24          False  1273.059337 -12.730593  1260.328744 -0.058520
# 25           True  1260.328744  25.206575  1285.535319 -0.039690
# 26           True  1285.535319  25.710706  1311.246025 -0.020484
# 27          False  1311.246025 -13.112460  1298.133565 -0.030279
# 28           True  1298.133565  25.962671  1324.096236 -0.010885
# 29          False  1324.096236 -13.240962  1310.855274 -0.020776
# 30          False  1310.855274 -13.108553  1297.746721 -0.030568
# 31           True  1297.746721  25.954934  1323.701656 -0.011180
# 32          False  1323.701656 -13.237017  1310.464639 -0.021068
# 33           True  1310.464639  26.209293  1336.673932 -0.001489
# 34          False  1336.673932 -13.366739  1323.307193 -0.011474
# 35           True  1323.307193  26.466144  1349.773336  0.000000
# 36          False  1349.773336 -13.497733  1336.275603 -0.010000
# 37           True  1336.275603  26.725512  1363.001115  0.000000
# 38           True  1363.001115  27.260022  1390.261137  0.000000
# 39           True  1390.261137  27.805223  1418.066360  0.000000
# 40          False  1418.066360 -14.180664  1403.885697 -0.010000
# 41          False  1403.885697 -14.038857  1389.846840 -0.019900
# 42           True  1389.846840  27.796937  1417.643776 -0.000298
# 43          False  1417.643776 -14.176438  1403.467339 -0.010295
# 44          False  1403.467339 -14.034673  1389.432665 -0.020192
# 45           True  1389.432665  27.788653  1417.221319 -0.000596
# 46           True  1417.221319  28.344426  1445.565745  0.000000
# 47          False  1445.565745 -14.455657  1431.110088 -0.010000
# 48          False  1431.110088 -14.311101  1416.798987 -0.019900
# 49          False  1416.798987 -14.167990  1402.630997 -0.029701

# %%
balance = 100000
win_rate = 0.5
risk_reward = 2
risk = 0.01
n = 200

n_sims = 5000
results = []

for i in range(n_sims):
    b, pp, md, _ = simulate(balance, win_rate, risk_reward, risk, n)
    results.append((b, pp, md))
    
df = pd.DataFrame(results, columns=["End Balance", "Profit%", "Max Drawdown"])

# %%
plt.hist(df['End Balance'], bins=20)
plt.title('Distribution of End Balance')
plt.xlabel('End Balance')
plt.ylabel('Occurrences')
# Out:
# Text(0, 0.5, 'Occurrences')

# %%
plt.hist((df['Profit%']-1)*100, bins=20)
plt.title('Distribution of Profit%')
plt.xlabel('Profit%')
plt.ylabel('Occurrences')
# Out:
# Text(0, 0.5, 'Occurrences')

# %%
plt.hist(abs(df['Max Drawdown'])*100, bins=20)
plt.title('Distribution of Max Drawdown')
plt.xlabel('Max Drawdown')
plt.ylabel('Occurrences')
# Out:
# Text(0, 0.5, 'Occurrences')

# %%
_, _, _, df = simulate(100000, 0.5, 2, 0.01, 500)

# %%
from matplotlib.ticker import (MultipleLocator, 
                               FormatStrFormatter, 
                               AutoMinorLocator) 

plt.plot(df['Balance'])
ax = plt.gca()
ax.yaxis.set_major_locator(MultipleLocator(10000)) 
ax.yaxis.set_major_formatter(FormatStrFormatter('% 1.0f'))

# %%
plt.bar(df.index, df['Profit'])
# Out:
# <BarContainer object of 500 artists>

# %%
df['Profit SMA'] = df['Profit'].rolling(50).mean()
plt.bar(df.index, df['Profit SMA'])
# Out:
# <BarContainer object of 500 artists>

# %%
avg_profit = df[df['Profit'] > 0]['Profit'].mean()
avg_loss = df[df['Profit'] < 0]['Profit'].mean()

# %%
avg_profit, avg_loss
# Out:
# (np.float64(7273.546712873562), np.float64(-3831.136881016415))

# %%
profit_factor = abs(avg_profit / avg_loss)
profit_factor
# Out:
# np.float64(1.8985348054032105)

# %%
plt.plot(df['Drawdown'])

# %%
plt.violinplot([
    df[df['Profit'] > 0]['Profit'],
    df[df['Profit'] < 0]['Profit']
], showmeans=True)
plt.title('Violin plot of Profit')
# Out:
# Text(0.5, 1.0, 'Violin plot of Profit')

# %%
df['Profit'] / df['Pre Balance']
# Out:
# 0      0.02
# 1      0.02
# 2      0.02
# 3      0.02
# 4      0.02
#        ...
# 495    0.02
# 496    0.02
# 497   -0.01
# 498   -0.01
# 499   -0.01
# Length: 500, dtype: float64
